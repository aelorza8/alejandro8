# %%
pip install pandas
# Out:
# ...
#      |████████████████████████████████| 11.3 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 15.7 MB 43.7 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 11.2 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 36.1 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 41.2 MB/s
# ...
#      |████████████████████████████████| 895 kB 48.8 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %ls datasets/
# Out:
# adult.csv                  coches.csv     nhanes_2015_2016.csv
# airline_data.csv           cwurData.csv   pokemon.csv
# antropometria00.csv        data.csv       reg_data.csv
# antropometria-dataset.csv  headbrain.csv  sample_pivot.csv
# Book3.csv                  marvel.csv     tips.csv
# Canada.xlsx                mic2.xlsx      weight-height.csv
# Cartwheeldata.csv          mic.xlsx       WineQT.csv
# census.csv                 movies.csv

# %%
df = pd.read_csv('datasets/WineQT.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
correlation = df['quality'].corr(df['fixed acidity'])
correlation
# Out:
# 0.1219700998972592

# %%
correlation = df['quality'].corr(df['volatile acidity'])
correlation
# Out:
# -0.4073935129243844

# %%
correlation = df['quality'].corr(df['citric acid'])
correlation
# Out:
# 0.24082083714719343

# %%
correlation = df['quality'].corr(df['residual sugar'])
correlation
# Out:
# 0.02200193057996685

# %%
correlation = df['quality'].corr(df['chlorides'])
correlation
# Out:
# -0.12408453132892874

# %%
correlation = df['quality'].corr(df['free sulfur dioxide'])
correlation
# Out:
# -0.06325964147253899

# %%
correlation = df['quality'].corr(df['total sulfur dioxide'])
correlation
# Out:
# -0.18333914747212995

# %%
correlation = df['quality'].corr(df['density'])
correlation
# Out:
# -0.17520792322642936

# %%
correlation = df['quality'].corr(df['pH'])
correlation
# Out:
# -0.05245303335788237

# %%
correlation = df['quality'].corr(df['sulphates'])
correlation
# Out:
# 0.2577102599306221

# %%
correlation = df['quality'].corr(df['alcohol'])
correlation
# Out:
# 0.4848662118060787

# %%
#Doing this we can see that the variables ALCOHOL, SULPHATES, CITRIC ACID, FIXED ACIDITY AND RESIDUAL SUGAR HAVE THE BEST CORRELATION WITH THE VARIABLE NAMED QUALITY

# %%
#¿Which variables have more correlation with the queality of the Wine?

#SULPHATE, ALCOHOL, CITRIC ACID, FIXED ACIDITY AND RESIDUAL SUGAR

# %%
df['alcohol'].plot(kind = 'hist')
plt.show()

# %%
#With this histogram it can be seen that the wines with the most frequency are the ones between 9 and 11 rate of alcohol.

# %%
df['quality'].plot(kind = 'hist')
plt.show()

# %%
#With this histogram we can answer the question " Which qualities are more present in the types of Wine in this data base.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.lmplot(x='quality',
           y='pH',
           data = df,
           fit_reg = False,
          )
plt.show()

# %%
#With this chart we can answer the question "¿Which type of quality has the biggest amount of PH?"

#The asnwer is the quality 5, 6 and 7.
