# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# %ls datasets/
# Out:
#  adult.csv                   cwurData.csv           pokemon.csv
#  airline_data.csv            data.csv               reg_data.csv
#  antropometria00.csv         headbrain.csv          sample_pivot.csv
#  antropometria-dataset.csv   mic.xlsx               tips.csv
#  Canada.xlsx                 movies.csv            'Untitled Folder'/
#  Cartwheeldata.csv           Netflix.csv            weight-height.csv
#  census.csv                  nhanes_2015_2016.csv

# %%
df = pd.read_csv('datasets/Netflix.csv')
df.head()
# Out:
#      Country  Total Library Size  No. of TV Shows  No. of Movies  \
# 0  Argentina                4760             3154           1606
# 1    Austria                5640             3779           1861
# 2    Bolivia                4991             3155           1836
# 3   Bulgaria                6797             4819           1978
# 4      Chile                4994             3156           1838
#
#    Cost Per Month - Basic ($)  Cost Per Month - Standard ($)  \
# 0                        3.74                           6.30
# 1                        9.03                          14.67
# 2                        7.99                          10.99
# 3                        9.03                          11.29
# 4                        7.07                           9.91
#
#    Cost Per Month - Premium ($)
# 0                          9.26
# 1                         20.32
# 2                         13.99
# 3                         13.54
# 4                         12.74

# %%
df['Total Library Size'].plot(kind = 'hist')
plt.show()

# %%
##As we can se the size of the library in each country is 
##different and the most comun number of series and movies rounds on 5000.

# %%
##After analysing the data i found out that there is a huge variation on the price of the subscription 
##depending on the country and its geographic location.

# %%
##I think that there is a correlation between the prices of the subcription and the size of their library.

# %%
correlation = df["Total Library Size"].corr(df["Cost Per Month - Basic ($)"])

correlation
# Out:
# -0.06287685725178405

# %%
import seaborn as sns

sns.regplot(x=df["Total Library Size"], y=df["Cost Per Month - Basic ($)"])
